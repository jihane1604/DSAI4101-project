# %%
import numpy as np
from src.b_models_impl import MyEmbeddingClient

# 1) Create the client (it will load your saved CNN)
emb_client = MyEmbeddingClient(
    model_path="C:/Users/sadek/OneDrive/Desktop/DSAI4101-project/models/classifier/simple_cnn.pth",
    classes_path="C:/Users/sadek/OneDrive/Desktop/DSAI4101-project/models/classifier/classes.json"
)

# 2) Dummy image (64x64x3 black image)
dummy_crop = np.zeros((64, 64, 3), dtype=np.uint8)

# 3) Get embedding
emb = emb_client.embed_crop(dummy_crop)

print("Embedding shape:", emb.shape)
print("Embedding dtype:", emb.dtype)
print("First 5 values:", emb[:5])
# Out:
# Embedding shape: (128,)
# Embedding dtype: float32
# First 5 values: [16.55474   0.        0.        5.419133  0.      ]
